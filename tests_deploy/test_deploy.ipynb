# %%
# Instala a versão que está no PyPI
# %pip install strkernels --upgrade --force-reinstall
# Out:
# ...
#   Using cached strkernels-0.2.12-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# ...
#   Using cached numpy-2.4.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Using cached strkernels-0.2.12-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
# Using cached numpy-2.4.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.3
#     Uninstalling numpy-2.4.3:
#       Successfully uninstalled numpy-2.4.3
#   Attempting uninstall: strkernels━━━━━━━━━━━━━━ 0/2 [numpy]
#     Found existing installation: strkernels 0.2.120/2 [numpy]
#     Uninstalling strkernels-0.2.12:━━━━━━━━━ 0/2 [numpy]
#       Successfully uninstalled strkernels-0.2.12 0/2 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [strkernels]2 [strkernels]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import strkernels
import os
import sys

# Local onde o Python encontrou o pacote
caminho_instalado = strkernels.__file__
print(f"📦 Pacote carregado de: {caminho_instalado}")

# O caminho do script atual (diretório de trabalho)
diretorio_atual = os.getcwd()

if diretorio_atual in caminho_instalado:
    print("⚠️ ATENÇÃO: O Python está carregando o código LOCAL da pasta atual.")
    print("Para um teste 100% isolado, mova este caderno para outra pasta ou renomeie a pasta 'strkernels/' local.")
elif "site-packages" in caminho_instalado:
    print("💎 SUCESSO: Isolação confirmada. Testando o binário instalado via pip.")
else:
    print("❓ Localização incomum detectada. Verifique seu sys.path.")
# Out:
# 📦 Pacote carregado de: /home/denilson/anaconda3/envs/strkernels_test/lib/python3.13/site-packages/strkernels/__init__.py
# 💎 SUCESSO: Isolação confirmada. Testando o binário instalado via pip.

# %%
tests_folder = "../tests"
# !python -m pytest {tests_folder} -v --color=yes
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.13.12, pytest-9.0.2, pluggy-1.5.0 -- /home/denilson/anaconda3/envs/strkernels_test/bin/python
# cachedir: .pytest_cache
# rootdir: /home/denilson/rep/dfb/Doutorado/strkernels
# configfile: pyproject.toml
# collected 32 items
#
# ../tests/1a_fixed_degree__normalizer-none_degree-1__test.py::TestKernelMatrix::test_empty_strings PASSED [  3%]
# ../tests/1a_fixed_degree__normalizer-none_degree-1__test.py::TestKernelMatrix::test_single_character_strings PASSED [  6%]
# ../tests/1a_fixed_degree__normalizer-none_degree-1__test.py::TestKernelMatrix::test_single_set PASSED [  9%]
# ../tests/1a_fixed_degree__normalizer-none_degree-1__test.py::TestKernelMatrix::test_two_sets PASSED [ 12%]
# ../tests/1b_fixed_degree__degree-1__test.py::TestKernelMatrix::test_empty_strings PASSED [ 15%]
# ...
